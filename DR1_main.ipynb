# %% [markdown]
# Basic DESI
#
# Here we are exploring more basic aspects of DESI data, such as
# * where the DESI pointings are
# * What is the format of DESI spectra
# * Redshift catalogs
# *

# %%
import astropy.table as atpy
import matplotlib.pyplot as plt
import astropy.io.fits as pyfits

# %%
tiles_T = atpy.Table().read('https://data.desi.lbl.gov/public/dr1/spectro/redux/iron/tiles-iron.csv')

# %%
tiles_T
# Out:
# <Table length=6101>
# TILEID SURVEY PROGRAM FAPRGRM ... LYA_EFFTIME_DARK GOALTYPE MINTFRAC LASTNIGHT
# int64   str7    str6   str16  ...     float64        str6   float64    int64
# ------ ------ ------- ------- ... ---------------- -------- -------- ---------
#  80615    cmx   other     m33 ...           3552.9    other      0.9  20201216
#  80609    sv1    dark  lrgqso ...          10690.3     dark      0.9  20201217
#  80606    sv1    dark     elg ...           7235.5     dark      0.9  20201219
#  80607    sv1    dark  lrgqso ...           8092.5     dark      0.9  20201219
#  80620    sv1    dark  lrgqso ...           5818.1     dark      0.9  20201221
#  80622    sv1    dark  lrgqso ...           6883.0     dark      0.9  20201221
#  80623    sv1    dark     elg ...           7151.4     dark      0.9  20201221
#  80611    sv1  bright  bgsmws ...            381.2   bright      0.9  20201222
#  80608    sv1    dark     elg ...          13539.6     dark      0.9  20201223
#    ...    ...     ...     ... ...              ...      ...      ...       ...
#  40469   main  backup  backup ...             40.6   backup     0.85  20220613
#  40453   main  backup  backup ...             41.4   backup     0.85  20220613
#  40445   main  backup  backup ...             53.2   backup     0.85  20220613
#  40439   main  backup  backup ...             54.7   backup     0.85  20220613
#  40353   main  backup  backup ...             30.0   backup     0.85  20220613
#  40350   main  backup  backup ...              7.4   backup     0.85  20220613
#  41035   main  backup  backup ...             40.1   backup     0.85  20220613
#  40275   main  backup  backup ...             43.1   backup     0.85  20220613
#  42339   main  backup  backup ...             20.8   backup     0.85  20220613
#  40336   main  backup  backup ...             27.8   backup     0.85  20220613

# %% [markdown]
# # Location of DESI main/bright tile centers

# %%
xind = (tiles_T['SURVEY']=='main') & (tiles_T['PROGRAM']=='bright')
plt.plot(tiles_T['TILERA'][xind],tiles_T['TILEDEC'][xind],'.',markersize=1)       
plt.xlabel('ra')
plt.ylabel('dec')
plt.xlim(*plt.xlim()[::-1])
# Out:
# (377.25525, -17.474249999999998)

# %% [markdown]
# # main/backup tile centers
#
# The footprints are very different between different survey/programs

# %%
xind = (tiles_T['SURVEY']=='main') & (tiles_T['PROGRAM']=='backup')
plt.plot(tiles_T['TILERA'][xind],tiles_T['TILEDEC'][xind],'.',markersize=2)       
plt.xlabel('ra')
plt.ylabel('dec')
plt.xlim(*plt.xlim()[::-1])
# Out:
# (336.4662, -16.0222)

# %%
# Effective exposure times for different tiles

# %%
plt.hist(tiles_T[(tiles_T['SURVEY']=='main')&(tiles_T['PROGRAM']=='bright')]['EFFTIME_SPEC'],bins=50);
plt.xlabel('Effective exposure time for main/bright tiles')
# Out:
# Text(0.5, 0, 'Effective exposure time for main/bright tiles')

# %%
# Structure of spectra

# %%
ls
# Out:
# coadd-main-bright-10813.fits  __pycache__/
# downloader.sh                 rvmod_coadd-main-bright-10813.fits
# DR1_tutorial.ipynb            rvpix_exp-sv3-bright.fits
# LoaTutorial.ipynb             rvtab_coadd-main-bright-10813.fits
# make_slim_catalog.py          slim_catalog_columns.md
# mwsall-pix-iron.fits          slim_catalog_columns.md~
# NOTES                         slim.fits
# NOTES.md                      toronto_tutorial/
# NOTES.md~                     Untitled.ipynb

# %%
pyfits.info('coadd-main-bright-10813.fits')
# Out:
# Filename: coadd-main-bright-10813.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      70   ()
#   1  FIBERMAP      1 BinTableHDU    193   411R x 67C   [K, J, D, D, E, E, E, K, B, 3A, D, J, I, 8A, J, J, 4A, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, I, E, E, E, E, K, 2A, E, E, E, E, 1A, K, K, K, K, K, K, D, D, I, E, I, I, E, E, E, E, D, E, D, E, E]
#   2  EXP_FIBERMAP    1 BinTableHDU     64   411R x 26C   [K, J, D, J, J, D, J, D, I, J, K, J, J, E, E, E, D, D, K, D, D, D, D, D, D, D]
#   3  B_WAVELENGTH    1 ImageHDU        10   (2751,)   float64
#   4  B_FLUX        1 ImageHDU        11   (2751, 411)   float32
#   5  B_IVAR        1 ImageHDU        11   (2751, 411)   float32
#   6  B_MASK        1 ImageHDU        10   (2751, 411)   int32
#   7  B_RESOLUTION    1 ImageHDU        11   (2751, 11, 411)   float32
#   8  R_WAVELENGTH    1 ImageHDU        10   (2326,)   float64
#   9  R_FLUX        1 ImageHDU        11   (2326, 411)   float32
#  10  R_IVAR        1 ImageHDU        11   (2326, 411)   float32
#  11  R_MASK        1 ImageHDU        10   (2326, 411)   int32
#  12  R_RESOLUTION    1 ImageHDU        11   (2326, 11, 411)   float32
#  13  Z_WAVELENGTH    1 ImageHDU        10   (2881,)   float64
#  14  Z_FLUX        1 ImageHDU        11   (2881, 411)   float32
#  15  Z_IVAR        1 ImageHDU        11   (2881, 411)   float32
#  16  Z_MASK        1 ImageHDU        10   (2881, 411)   int32
#  17  Z_RESOLUTION    1 ImageHDU        11   (2881, 11, 411)   float32
#  18  SCORES        1 BinTableHDU     96   411R x 42C   [K, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E]

# %% [markdown]
# # Extensions
#
# *  WAVELENGTH/FLUX/IVAR/MASK/RESOLUTION -- wavelength, flux, inverse variance, mask, resolution matrix for each arm
# *    FIBERMAP -- table summarizing each target, targeting bits, photometry
# *    EXP_FIBERMAP -- fibermap rows for multiple exposures contributing to the stack
# *    SCORES -- key infomation about quality of spectra (S/N, effective exposure times etc)

# %%
fp = pyfits.open('coadd-main-bright-10813.fits')
print (fp['FIBERMAP'].columns)
# Out:
# ColDefs(
#     name = 'TARGETID'; format = 'K'
#     name = 'COADD_FIBERSTATUS'; format = 'J'
#     name = 'TARGET_RA'; format = 'D'
#     name = 'TARGET_DEC'; format = 'D'
#     name = 'PMRA'; format = 'E'
#     name = 'PMDEC'; format = 'E'
#     name = 'REF_EPOCH'; format = 'E'
#     name = 'FA_TARGET'; format = 'K'
#     name = 'FA_TYPE'; format = 'B'
#     name = 'OBJTYPE'; format = '3A'
#     name = 'SUBPRIORITY'; format = 'D'
#     name = 'OBSCONDITIONS'; format = 'J'
#     name = 'RELEASE'; format = 'I'
#     name = 'BRICKNAME'; format = '8A'
#     name = 'BRICKID'; format = 'J'
#     name = 'BRICK_OBJID'; format = 'J'
#     name = 'MORPHTYPE'; format = '4A'
#     name = 'EBV'; format = 'E'
#     name = 'FLUX_G'; format = 'E'
#     name = 'FLUX_R'; format = 'E'
#     name = 'FLUX_Z'; format = 'E'
#     name = 'FLUX_W1'; format = 'E'
#     name = 'FLUX_W2'; format = 'E'
#     name = 'FLUX_IVAR_G'; format = 'E'
#     name = 'FLUX_IVAR_R'; format = 'E'
#     name = 'FLUX_IVAR_Z'; format = 'E'
#     name = 'FLUX_IVAR_W1'; format = 'E'
#     name = 'FLUX_IVAR_W2'; format = 'E'
#     name = 'FIBERFLUX_G'; format = 'E'
#     name = 'FIBERFLUX_R'; format = 'E'
#     name = 'FIBERFLUX_Z'; format = 'E'
#     name = 'FIBERTOTFLUX_G'; format = 'E'
#     name = 'FIBERTOTFLUX_R'; format = 'E'
#     name = 'FIBERTOTFLUX_Z'; format = 'E'
#     name = 'MASKBITS'; format = 'I'
#     name = 'SERSIC'; format = 'E'
#     name = 'SHAPE_R'; format = 'E'
#     name = 'SHAPE_E1'; format = 'E'
#     name = 'SHAPE_E2'; format = 'E'
#     name = 'REF_ID'; format = 'K'
#     name = 'REF_CAT'; format = '2A'
#     name = 'GAIA_PHOT_G_MEAN_MAG'; format = 'E'
#     name = 'GAIA_PHOT_BP_MEAN_MAG'; format = 'E'
#     name = 'GAIA_PHOT_RP_MEAN_MAG'; format = 'E'
#     name = 'PARALLAX'; format = 'E'
#     name = 'PHOTSYS'; format = '1A'
#     name = 'PRIORITY_INIT'; format = 'K'
#     name = 'NUMOBS_INIT'; format = 'K'
#     name = 'DESI_TARGET'; format = 'K'
#     name = 'BGS_TARGET'; format = 'K'
#     name = 'MWS_TARGET'; format = 'K'
#     name = 'SCND_TARGET'; format = 'K'
#     name = 'PLATE_RA'; format = 'D'
#     name = 'PLATE_DEC'; format = 'D'
#     name = 'COADD_NUMEXP'; format = 'I'
#     name = 'COADD_EXPTIME'; format = 'E'
#     name = 'COADD_NUMNIGHT'; format = 'I'
#     name = 'COADD_NUMTILE'; format = 'I'
#     name = 'MEAN_DELTA_X'; format = 'E'
#     name = 'RMS_DELTA_X'; format = 'E'
#     name = 'MEAN_DELTA_Y'; format = 'E'
#     name = 'RMS_DELTA_Y'; format = 'E'
#     name = 'MEAN_FIBER_RA'; format = 'D'
#     name = 'STD_FIBER_RA'; format = 'E'
#     name = 'MEAN_FIBER_DEC'; format = 'D'
#     name = 'STD_FIBER_DEC'; format = 'E'
#     name = 'MEAN_PSF_TO_FIBER_SPECFLUX'; format = 'E'
# )
